# %%
# !pip install pycocotools
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd 
import os
from pycocotools.coco import COCO
import skimage.io as io
import matplotlib.pyplot as plt
from pathlib import Path

# %%
dataDir=Path('/content/drive/MyDrive/Dinosaurs.v1i.coco/train')
annFile = Path('/content/drive/MyDrive/Dinosaurs.v1i.coco/train/_annotations.coco.json')
coco = COCO(annFile)
imgIds = coco.getImgIds()
dinosaurs = coco.loadCats(coco.getCatIds())
categories = [dinosaur['name'] for dinosaur in dinosaurs]
print(f"Количество категорий: {len(categories)}")
print()
print("Категории:")
print(categories)
# Out:
# loading annotations into memory...
# Done (t=0.48s)
# creating index...
# index created!
# Количество категорий: 4
#
# Категории:
# ['dinosaurs', 'Carnotaurus', 'Stegosaurus', 'Triceratops']

# %%
imgs = coco.loadImgs(imgIds[7:16])
_,axs = plt.subplots(len(imgs),2,figsize=(10,5 * len(imgs)))
for img, ax in zip(imgs, axs):
    I = io.imread(dataDir/img['file_name'])
    annIds = coco.getAnnIds(imgIds=[img['id']])
    anns = coco.loadAnns(annIds)
    ax[0].imshow(I)
    ax[1].imshow(I)
    plt.sca(ax[1])
    coco.showAnns(anns, draw_bbox=True)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
